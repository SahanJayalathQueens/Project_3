# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
zil = pd.read_csv(r'C:\Users\Sahan\Documents\Project_3\CSV\zillow NY for-sale properties.csv')
zil
# Out:
#                                             property_url  property_id  \
# 0      https://www.zillow.com/homedetails/97-Reservoi...   2066966109
# 1      https://www.zillow.com/homedetails/524-County-...     29962801
# 2      https://www.zillow.com/homedetails/32-Brooksid...     29962922
# 3      https://www.zillow.com/homedetails/252-Elmwood...     29971014
# 4      https://www.zillow.com/homedetails/3526-Kentuc...     29974158
# ...                                                  ...          ...
# 96804  https://www.zillow.com/homedetails/333-Lathrop...     32301630
# 96805  https://www.zillow.com/homedetails/128-W-138th...    305898907
# 96806  https://www.zillow.com/homedetails/70-Park-Ter...   2064168641
# 96807  https://www.zillow.com/homedetails/77-Park-Ter...    122143341
# 96808  https://www.zillow.com/homedetails/77-Park-Ter...     80624971
#
#                                            address         street_name  \
# ...

# %%
zil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96809 entries, 0 to 96808
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   property_url        96809 non-null  object
#  1   property_id         96809 non-null  int64
#  2   address             96809 non-null  object
#  3   street_name         96802 non-null  object
#  4   apartment           12765 non-null  object
#  5   city                96809 non-null  object
#  6   state               96809 non-null  object
#  7   latitude            92392 non-null  float64
#  8   longitude           92392 non-null  float64
#  9   postcode            96807 non-null  float64
#  10  price               96809 non-null  float64
#  11  bedroom_number      87030 non-null  float64
#  12  bathroom_number     91152 non-null  float64
#  13  price_per_unit      69760 non-null  float64
#  14  living_space        70643 non-null  float64
# ...

# %%
zil['price'].value_counts()
# Out:
# 699000.0    856
# 599000.0    805
# 799000.0    764
# 499000.0    727
# 899000.0    596
#            ...
# 569390.0      1
# 962587.0      1
# 415750.0      1
# 19.0          1
# 39950.0       1
# Name: price, Length: 6868, dtype: int64

# %%
number_of_brooklyn = (zil['city'] == 'Brooklyn').sum()
number_of_brooklyn
# Out:
# 9901

# %%
brooklyn_df = zil[zil['city'] == 'Brooklyn'][[ 'city', 'state', 'price', 'bedroom_number', 'bathroom_number', 'price_per_unit']]
brooklyn_df
# Out:
#            city state      price  bedroom_number  bathroom_number  \
# 49324  Brooklyn    NY   459999.0             2.0              1.0
# 49328  Brooklyn    NY   758000.0             2.0              2.0
# 49332  Brooklyn    NY   849000.0             4.0              2.0
# 49335  Brooklyn    NY   788000.0             4.0              3.0
# 49338  Brooklyn    NY   550000.0             3.0              2.0
# ...         ...   ...        ...             ...              ...
# 96739  Brooklyn    NY  1599000.0             7.0              3.0
# 96740  Brooklyn    NY  2550000.0            12.0              4.0
# 96741  Brooklyn    NY   965000.0             9.0              5.0
# 96742  Brooklyn    NY   525000.0             2.0              2.0
# 96743  Brooklyn    NY   569000.0             2.0              2.0
#
#        price_per_unit
# 49324          1008.0
# 49328           421.0
# 49332           463.0
# 49335           525.0
# 49338           361.0
# ...               ...
# ...

# %%
brooklyn_df.to_csv('brooklyn_df.csv', index=False)

# %%
columns_to_drop = ['property_url', 'property_id', 'total_num_units', 'agent_name', 'agent_phone','is_owned_by_zillow','agency_name', 'broker_id', 'apartment', 'postcode', 'RunDate','year_build']
zil_df = zil.drop(columns = columns_to_drop)
zil_df
# Out:
#                                            address         street_name  \
# 0                   97 Reservoir, Hawley, NY 18428           Reservoir
# 1             524 County Road 64, Elmira, NY 14903      County Road 64
# 2               32 Brookside Cir, Elmira, NY 14903       Brookside Cir
# 3        252 Elmwood Ave, Elmira Heights, NY 14903         Elmwood Ave
# 4      3526 Kentucky Ave, Elmira Heights, NY 14903        Kentucky Ave
# ...                                            ...                 ...
# 96804     333 Lathrop Ave, Staten Island, NY 10302         Lathrop Ave
# 96805       128 W 138th St #5I, New York, NY 10030      W 138th St #5I
# 96806         70 Park Ter E #6, New York, NY 10034       Park Ter E #6
# 96807    77 Park Ter E APT D76, New York, NY 10034  Park Ter E APT D76
# 96808    77 Park Ter E APT D35, New York, NY 10034  Park Ter E APT D35
#
#                  city state   latitude  longitude     price  bedroom_number  \
# ...

# %%
zil_df['city'].value_counts().head(30)
# Out:
# New York            12579
# Brooklyn             9901
# Flushing             2774
# Bronx                2770
# Jamaica              1763
# Staten Island        1657
# Buffalo              1553
# Rochester            1435
# Syracuse              763
# Forest Hills          698
# Schenectady           694
# Yonkers               685
# Long Island City      680
# Albany                541
# White Plains          438
# Jackson Heights       403
# Poughkeepsie          394
# Astoria               393
# Great Neck            389
# Troy                  388
# Scarsdale             379
# Binghamton            378
# Niagara Falls         349
# Rego Park             336
# Bayside               328
# Newburgh              322
# East Hampton          319
# Middletown            309
# Saratoga Springs      301
# Mount Vernon          300
# Name: city, dtype: int64

# %%
zil_df['property_type'].value_counts()
# Out:
# SINGLE_FAMILY    42738
# CONDO            29508
# MULTI_FAMILY     11812
# LOT               9559
# TOWNHOUSE         1792
# MANUFACTURED       842
# APARTMENT          558
# Name: property_type, dtype: int64

# %%
values_to_replace = ['Flushing', 'Jamaica', 'Forest Hills', 'Long Island City', 
                     'Jackson Heights', 'Astoria', 'Rego Park', 'Bayside']

# %%
zil_df['city'] = zil_df['city'].replace(values_to_replace, 'Queens')

# %%
zil_df
# Out:
#                                            address         street_name  \
# 0                   97 Reservoir, Hawley, NY 18428           Reservoir
# 1             524 County Road 64, Elmira, NY 14903      County Road 64
# 2               32 Brookside Cir, Elmira, NY 14903       Brookside Cir
# 3        252 Elmwood Ave, Elmira Heights, NY 14903         Elmwood Ave
# 4      3526 Kentucky Ave, Elmira Heights, NY 14903        Kentucky Ave
# ...                                            ...                 ...
# 96804     333 Lathrop Ave, Staten Island, NY 10302         Lathrop Ave
# 96805       128 W 138th St #5I, New York, NY 10030      W 138th St #5I
# 96806         70 Park Ter E #6, New York, NY 10034       Park Ter E #6
# 96807    77 Park Ter E APT D76, New York, NY 10034  Park Ter E APT D76
# 96808    77 Park Ter E APT D35, New York, NY 10034  Park Ter E APT D35
#
#                  city state   latitude  longitude     price  bedroom_number  \
# ...

# %%
zil_df['city'].value_counts().head(30)
# Out:
# New York            12579
# Brooklyn             9901
# Queens               7475
# Bronx                2770
# Staten Island        1657
# Buffalo              1553
# Rochester            1435
# Syracuse              763
# Schenectady           694
# Yonkers               685
# Albany                541
# White Plains          438
# Poughkeepsie          394
# Great Neck            389
# Troy                  388
# Scarsdale             379
# Binghamton            378
# Niagara Falls         349
# Newburgh              322
# East Hampton          319
# Middletown            309
# Saratoga Springs      301
# Mount Vernon          300
# Utica                 289
# Woodside              285
# East Elmhurst         283
# New Rochelle          273
# Ithaca                272
# Bronxville            267
# Long Beach            260
# Name: city, dtype: int64

# %%
values_to_keep = ['New York', 'Brooklyn', 'Bronx', 'Queens', 'Staten Island']

# %%
filtered_df = zil_df[zil_df['city'].isin(values_to_keep)]

# %%
filtered_df
# Out:
#                                             address         street_name  \
# 38193            14004 135th Ave, Jamaica, NY 11436           135th Ave
# 38197            120-28 142nd St, Jamaica, NY 11436         28 142nd St
# 38201             12028 142nd St, Jamaica, NY 11436            142nd St
# 38205       117-11 Inwood Street, Jamaica, NY 11436    11 Inwood Street
# 38209  130-11 147th Street, S. Ozone Park, NY 11436     11 147th Street
# ...                                             ...                 ...
# 96804      333 Lathrop Ave, Staten Island, NY 10302         Lathrop Ave
# 96805        128 W 138th St #5I, New York, NY 10030      W 138th St #5I
# 96806          70 Park Ter E #6, New York, NY 10034       Park Ter E #6
# 96807     77 Park Ter E APT D76, New York, NY 10034  Park Ter E APT D76
# 96808     77 Park Ter E APT D35, New York, NY 10034  Park Ter E APT D35
#
#                 city state   latitude  longitude     price  bedroom_number  \
# ...

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34382 entries, 38193 to 96808
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   address          34382 non-null  object
#  1   street_name      34381 non-null  object
#  2   city             34382 non-null  object
#  3   state            34382 non-null  object
#  4   latitude         33936 non-null  float64
#  5   longitude        33936 non-null  float64
#  6   price            34382 non-null  float64
#  7   bedroom_number   33462 non-null  float64
#  8   bathroom_number  34107 non-null  float64
#  9   price_per_unit   26466 non-null  float64
#  10  living_space     26513 non-null  float64
#  11  land_space       12018 non-null  float64
#  12  land_space_unit  12018 non-null  object
#  13  property_type    34382 non-null  object
#  14  property_status  34382 non-null  object
#  15  listing_age      34382 non-null  int64
# ...

# %%
columns_to_export = ['street_name', 'city', 'price', 'bedroom_number', 
                     'price_per_unit', 'living_space', 'land_space', 
                     'land_space_unit', 'property_type']

# %%
export_df = filtered_df[columns_to_export]

# %%
filtered_df.to_csv('filtered_df.csv', index=False)  # Change the filename as needed
