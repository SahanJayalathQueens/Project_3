# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
bx = pd.read_csv(r'C:\Users\Sahan\Documents\Phase_3_Project\CSV\Bronx_2020.csv')
bx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 4 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Fact                                   79 non-null     object
#  1   Fact Note                              22 non-null     object
#  2   Bronx County, New York                 64 non-null     object
#  3   Value Note for Bronx County, New York  0 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 2.8+ KB

# %%
bk =  pd.read_csv(r'C:\Users\Sahan\Documents\Phase_3_Project\CSV\Brooklyn_2020.csv')

# %%
bk
# Out:
#                                                  Fact  \
# 0         Population estimates, July 1, 2023, (V2023)
# 1   Population estimates base, April 1, 2020, (V2023)
# 2   Population, percent change - April 1, 2020 (es...
# 3                   Population, Census, April 1, 2020
# 4                   Population, Census, April 1, 2010
# ..                                                ...
# 80                                                  S
# 81                                                  X
# 82                                                  Z
# 83                                                  -
# 84                                                  N
#
#                                             Fact Note Kings County, New York  \
# 0                                                 NaN              2,561,225
# 1                                                 NaN              2,736,119
# 2                                                 NaN                  -6.4%
# ...

# %%
qns = pd.read_csv(r'C:\Users\Sahan\Documents\Phase_3_Project\CSV\Queens_2020.csv')

# %%
qns
# Out:
#                                                  Fact  \
# 0         Population estimates, July 1, 2023, (V2023)
# 1   Population estimates base, April 1, 2020, (V2023)
# 2   Population, percent change - April 1, 2020 (es...
# 3                   Population, Census, April 1, 2020
# 4                   Population, Census, April 1, 2010
# ..                                                ...
# 80                                                  S
# 81                                                  X
# 82                                                  Z
# 83                                                  -
# 84                                                  N
#
#                                             Fact Note Queens County, New York  \
# 0                                                 NaN               2,252,196
# 1                                                 NaN               2,405,425
# 2                                                 NaN                   -6.4%
# ...

# %%
si = pd.read_csv(r'C:\Users\Sahan\Documents\Phase_3_Project\CSV\Staten_2020.csv')
si
# Out:
#                                                  Fact  \
# 0         Population estimates, July 1, 2023, (V2023)
# 1   Population estimates base, April 1, 2020, (V2023)
# 2   Population, percent change - April 1, 2020 (es...
# 3                   Population, Census, April 1, 2020
# 4                   Population, Census, April 1, 2010
# ..                                                ...
# 80                                                  S
# 81                                                  X
# 82                                                  Z
# 83                                                  -
# 84                                                  N
#
#                                             Fact Note  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...

# %%
mn = pd.read_csv(r'C:\Users\Sahan\Documents\Phase_3_Project\CSV\Manhattan_2020.csv')
mn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 4 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Fact                                      79 non-null     object
#  1   Fact Note                                 22 non-null     object
#  2   New York County, New York                 64 non-null     object
#  3   Value Note for New York County, New York  0 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 2.8+ KB

# %%
mn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Fact                       79 non-null     object
#  1   New York County, New York  64 non-null     object
# dtypes: object(2)
# memory usage: 1.5+ KB

# %%
mn
# Out:
#                                                  Fact  \
# 0         Population estimates, July 1, 2023, (V2023)
# 1   Population estimates base, April 1, 2020, (V2023)
# 2   Population, percent change - April 1, 2020 (es...
# 3                   Population, Census, April 1, 2020
# 4                   Population, Census, April 1, 2010
# ..                                                ...
# 80                                                  S
# 81                                                  X
# 82                                                  Z
# 83                                                  -
# 84                                                  N
#
#    New York County, New York
# 0                  1,597,451
# 1                  1,694,250
# 2                      -5.7%
# 3                  1,694,251
# 4                  1,585,873
# ..                       ...
# 80                       NaN
# 81                       NaN
# 82                       NaN
# ...

# %%
mn['count'] = 1  # Add a dummy count column for pivoting
pivoted_df = mn.pivot_table(index=None, columns='Fact', values='New York County, New York', aggfunc='first')

# Convert the pivoted DataFrame to a single row
single_row_df = pd.DataFrame([pivoted_df.values.flatten()], columns=pivoted_df.columns)

# Display the resulting DataFrame
single_row_df
# Out:
# Fact All employer firms, Reference year 2017  \
# 0                                     86,330
#
# Fact American Indian and Alaska Native alone, percent Asian alone, percent  \
# 0                                                1.2%                13.6%
#
# Fact Bachelor's degree or higher, percent of persons age 25 years+, 2018-2022  \
# 0                                                 62.8%
#
# Fact Black or African American alone, percent Building Permits, 2023  \
# 0                                       18.4%                  3,030
#
# Fact FIPS Code Female persons, percent  \
# 0      "36061"                   52.3%
#
# Fact Foreign born persons, percent, 2018-2022  \
# 0                                       28.1%
#
# Fact High school graduate or higher, percent of persons age 25 years+, 2018-2022  \
# 0                                                 88.5%
#
# Fact  ... Total retail sales per capita, 2017  \
# 0     ...                             $33,587
#
# ...

# %%
import pandas as pd

# Function to pivot DataFrame
def pivot_county_df(df, county_name):
    # Create a new DataFrame where 'Fact' values are columns
    pivoted_df = df.pivot_table(index=None, columns='Fact', values=county_name, aggfunc='first')
    
    # Convert the pivoted DataFrame to a single row
    single_row_df = pd.DataFrame([pivoted_df.values.flatten()], columns=pivoted_df.columns)
    
    return single_row_df

# Assuming your DataFrames are named bx, bk, qns, si
# Replace 'County Column' with the respective county names
bx_pivoted = pivot_county_df(bx, 'Bronx County, New York')
bk_pivoted = pivot_county_df(bk, 'Kings County, New York')
qns_pivoted = pivot_county_df(qns, 'Queens County, New York')
si_pivoted = pivot_county_df(si, 'Richmond County, New York')

# Now you have pivoted DataFrames for each county
print("Bronx Pivoted DataFrame:\n", bx_pivoted)
print("Kings Pivoted DataFrame:\n", bk_pivoted)
print("Queens Pivoted DataFrame:\n", qns_pivoted)
print("Richmond Pivoted DataFrame:\n", si_pivoted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 15
#      11     return single_row_df
#      13 # Assuming your DataFrames are named bx, bk, qns, si
#      14 # Replace 'County Column' with the respective county names
# ---> 15 bx_pivoted = pivot_county_df(bx, 'Bronx County, New York')
#      16 bk_pivoted = pivot_county_df(bk, 'Kings County, New York')
#      17 qns_pivoted = pivot_county_df(qns, 'Queens County, New York')
#
# NameError: name 'bx' is not defined

# %%
# Function to pivot DataFrame
def pivot_county_df(df, county_col):
    # Pivot the DataFrame
    pivoted_df = df.pivot_table(index=None, columns='Fact', values=county_col, aggfunc='first')
    
    # Convert the pivoted DataFrame to a single row
    single_row_df = pd.DataFrame([pivoted_df.values.flatten()], columns=pivoted_df.columns)
    
    return single_row_df

# Assuming your DataFrames are already defined as bx, bk, qns, si
# Pivot each county DataFrame
bx_pivoted = pivot_county_df(bx, 'Bronx County, New York')
bk_pivoted = pivot_county_df(bk, 'Kings County, New York')
qns_pivoted = pivot_county_df(qns, 'Queens County, New York')
si_pivoted = pivot_county_df(si, 'Richmond County, New York')

# Display results
bx_pivoted
# Out:
# Fact All employer firms, Reference year 2017  \
# 0                                     15,640
#
# Fact American Indian and Alaska Native alone, percent Asian alone, percent  \
# 0                                                3.1%                 5.0%
#
# Fact Bachelor's degree or higher, percent of persons age 25 years+, 2018-2022  \
# 0                                                 21.2%
#
# Fact Black or African American alone, percent Building Permits, 2023  \
# 0                                       45.1%                  5,468
#
# Fact FIPS Code Female persons, percent  \
# 0      "36005"                   52.8%
#
# Fact Foreign born persons, percent, 2018-2022  \
# 0                                       33.9%
#
# Fact High school graduate or higher, percent of persons age 25 years+, 2018-2022  \
# 0                                                 74.5%
#
# Fact  ... Total retail sales per capita, 2017  \
# 0     ...                              $6,355
#
# ...

# %%
# Combine all pivoted DataFrames into one
combined_df = pd.concat([bx_pivoted, bk_pivoted, qns_pivoted, si_pivoted, single_row_df], ignore_index=True)

# Display the combined DataFrame
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 64 columns):
#  #   Column                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                  --------------  -----
#  0   All employer firms, Reference year 2017                                                 5 non-null      object
#  1   American Indian and Alaska Native alone, percent                                        5 non-null      object
#  2   Asian alone, percent                                                                    5 non-null      object
#  3   Bachelor's degree or higher, percent of persons age 25 years+, 2018-2022                5 non-null      object
#  4   Black or African American alone, percent                                                5 non-null      object
# ...

# %%
# Combine all pivoted DataFrames into one
combined_df = pd.concat([bx_pivoted, bk_pivoted, qns_pivoted, si_pivoted, single_row_df], ignore_index=True)

# Replace the first column with 'Borough' and set the corresponding names
combined_df.insert(0, 'Borough', ['Bronx', 'Brooklyn', 'Queens', 'Staten Island', 'Manhattan'])

# Display the modified combined DataFrame
pd.set_option('display.max_columns', None)
combined_df
# Out:
# Fact        Borough All employer firms, Reference year 2017  \
# 0             Bronx                                  15,640
# 1          Brooklyn                                  52,976
# 2            Queens                                  44,964
# 3     Staten Island                                   8,192
# 4         Manhattan                                  86,330
#
# Fact American Indian and Alaska Native alone, percent Asian alone, percent  \
# 0                                                3.1%                 5.0%
# 1                                                1.0%                13.1%
# 2                                                1.5%                28.0%
# 3                                                0.8%                14.5%
# 4                                                1.2%                13.6%
#
# Fact Bachelor's degree or higher, percent of persons age 25 years+, 2018-2022  \
# 0                                                 21.2%
# ...
